# %%
import findspark

# %%
findspark.init()

# %%
import pyspark
from pyspark.sql import SparkSession

# %%
spark_session = SparkSession.builder.getOrCreate()

# %%
# testing the installation
test = spark_session.sql("SELECT 'spark hello' as Hello")

# %%
test.show()
# Out:
# +-----------+
# |      Hello|
# +-----------+
# |spark hello|
# +-----------+
